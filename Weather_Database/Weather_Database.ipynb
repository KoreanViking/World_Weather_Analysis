# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
Cities=[]


# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in Cities:
        Cities.append(city)

# Print the city count to confirm sufficient count
len(Cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(Cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        city_desc = city_weather["weather"][0]["description"]       

            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coihaique
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | qasigiannguit
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | doembang nangbuat
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | santa cruz de tenerife
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | atambua
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 1 | poum
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | tingrela
# City not found. Skipping...
# Processing Record 25 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 1 | egvekinot
# Processing Record 27 of Set 1 | kibala
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | neiafu
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | paamiut
# Processing Record 35 of Set 1 | vikhorevka
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | sioux lookout
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | menongue
# Processing Record 42 of Set 1 | saint-augustin
# Processing Record 43 of Set 1 | vila franca do campo
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | rocha
# Processing Record 47 of Set 1 | chapleau
# Processing Record 48 of Set 1 | westpunt
# City not found. Skipping...
# Processing Record 49 of Set 1 | gizo
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | tigil
# Processing Record 3 of Set 2 | sabang
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | tevaitoa
# Processing Record 6 of Set 2 | shorewood
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | yerbogachen
# Processing Record 10 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | guerrero negro
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | yaan
# Processing Record 19 of Set 2 | samarai
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | margate
# Processing Record 22 of Set 2 | mayo
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | carbonia
# Processing Record 25 of Set 2 | mitsamiouli
# Processing Record 26 of Set 2 | rassvet
# Processing Record 27 of Set 2 | riyadh
# Processing Record 28 of Set 2 | orlik
# Processing Record 29 of Set 2 | karaton
# Processing Record 30 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | praya
# Processing Record 33 of Set 2 | sao jose da coroa grande
# Processing Record 34 of Set 2 | baghdad
# Processing Record 35 of Set 2 | san quintin
# Processing Record 36 of Set 2 | yulara
# Processing Record 37 of Set 2 | belaya gora
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | havelock
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | aitape
# Processing Record 43 of Set 2 | poso
# Processing Record 44 of Set 2 | ballina
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | veraval
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | grafton
# Processing Record 2 of Set 3 | lasa
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | macon
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 3 | santa fe
# Processing Record 7 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 3 | gombe
# Processing Record 11 of Set 3 | bereda
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | richards bay
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | edd
# Processing Record 17 of Set 3 | cabog
# Processing Record 18 of Set 3 | vuktyl
# Processing Record 19 of Set 3 | bakong
# Processing Record 20 of Set 3 | tessalit
# Processing Record 21 of Set 3 | portland
# Processing Record 22 of Set 3 | emba
# Processing Record 23 of Set 3 | linxia
# Processing Record 24 of Set 3 | namibe
# Processing Record 25 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | naryan-mar
# Processing Record 29 of Set 3 | bandarbeyla
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | touros
# Processing Record 32 of Set 3 | houston
# Processing Record 33 of Set 3 | leshukonskoye
# Processing Record 34 of Set 3 | padang
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | basoko
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | matagami
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | sabla
# Processing Record 41 of Set 3 | sorland
# Processing Record 42 of Set 3 | ixtapa
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | general roca
# Processing Record 45 of Set 3 | coleraine
# Processing Record 46 of Set 3 | shahreza
# Processing Record 47 of Set 3 | deputatskiy
# Processing Record 48 of Set 3 | norrtalje
# Processing Record 49 of Set 3 | lompoc
# Processing Record 50 of Set 3 | port keats
# Processing Record 1 of Set 4 | puerto maldonado
# Processing Record 2 of Set 4 | belozerskoye
# Processing Record 3 of Set 4 | zemio
# Processing Record 4 of Set 4 | tabou
# Processing Record 5 of Set 4 | severo-kurilsk
# Processing Record 6 of Set 4 | jishou
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | palmas
# Processing Record 9 of Set 4 | pisco
# Processing Record 10 of Set 4 | vestmannaeyjar
# Processing Record 11 of Set 4 | bushehr
# Processing Record 12 of Set 4 | ankang
# Processing Record 13 of Set 4 | los llanos de aridane
# Processing Record 14 of Set 4 | pacific grove
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | springbok
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | concordia
# Processing Record 20 of Set 4 | cherskiy
# Processing Record 21 of Set 4 | smithers
# Processing Record 22 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 4 | wanning
# Processing Record 24 of Set 4 | ha tinh
# Processing Record 25 of Set 4 | chapais
# Processing Record 26 of Set 4 | yauya
# Processing Record 27 of Set 4 | hermanus
# Processing Record 28 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | houlton
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 4 | dakar
# Processing Record 33 of Set 4 | honiara
# Processing Record 34 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 4 | barranca
# Processing Record 37 of Set 4 | dina
# Processing Record 38 of Set 4 | derzhavinsk
# Processing Record 39 of Set 4 | maniitsoq
# Processing Record 40 of Set 4 | kantunilkin
# Processing Record 41 of Set 4 | fairbanks
# Processing Record 42 of Set 4 | pipar
# Processing Record 43 of Set 4 | hasanabad
# Processing Record 44 of Set 4 | kharp
# Processing Record 45 of Set 4 | columbus
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | mar del plata
# Processing Record 48 of Set 4 | hauterive
# Processing Record 49 of Set 4 | cabo san lucas
# Processing Record 50 of Set 4 | inirida
# Processing Record 1 of Set 5 | necochea
# Processing Record 2 of Set 5 | pangnirtung
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | santa maria del oro
# Processing Record 5 of Set 5 | krasnoselkup
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | kavieng
# Processing Record 8 of Set 5 | shitanjing
# Processing Record 9 of Set 5 | makakilo city
# Processing Record 10 of Set 5 | salvador
# Processing Record 11 of Set 5 | maragogi
# Processing Record 12 of Set 5 | masvingo
# Processing Record 13 of Set 5 | labuhan
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | lodja
# Processing Record 16 of Set 5 | kangar
# Processing Record 17 of Set 5 | cabedelo
# Processing Record 18 of Set 5 | beruwala
# Processing Record 19 of Set 5 | luanda
# Processing Record 20 of Set 5 | ilulissat
# Processing Record 21 of Set 5 | sorong
# Processing Record 22 of Set 5 | tiksi
# Processing Record 23 of Set 5 | lazaro cardenas
# Processing Record 24 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 5 | zhezkazgan
# Processing Record 26 of Set 5 | remontnoye
# Processing Record 27 of Set 5 | el naranjo
# Processing Record 28 of Set 5 | haines junction
# Processing Record 29 of Set 5 | san patricio
# Processing Record 30 of Set 5 | nikolskoye
# Processing Record 31 of Set 5 | broken hill
# Processing Record 32 of Set 5 | pilar
# Processing Record 33 of Set 5 | srednekolymsk
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | poykovskiy
# Processing Record 36 of Set 5 | san policarpo
# Processing Record 37 of Set 5 | krasnaya gora
# Processing Record 38 of Set 5 | hobyo
# Processing Record 39 of Set 5 | radomsko
# Processing Record 40 of Set 5 | itoman
# Processing Record 41 of Set 5 | hailar
# Processing Record 42 of Set 5 | new norfolk
# Processing Record 43 of Set 5 | tyrma
# Processing Record 44 of Set 5 | souillac
# Processing Record 45 of Set 5 | harrison
# Processing Record 46 of Set 5 | krasavino
# Processing Record 47 of Set 5 | assiniboia
# Processing Record 48 of Set 5 | olafsvik
# Processing Record 49 of Set 5 | biltine
# Processing Record 50 of Set 5 | valdivia
# Processing Record 1 of Set 6 | mehamn
# Processing Record 2 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | novosergiyevka
# Processing Record 5 of Set 6 | avarua
# Processing Record 6 of Set 6 | chuy
# Processing Record 7 of Set 6 | crateus
# Processing Record 8 of Set 6 | gonnoi
# Processing Record 9 of Set 6 | nemuro
# Processing Record 10 of Set 6 | khon kaen
# Processing Record 11 of Set 6 | chinsali
# Processing Record 12 of Set 6 | fortuna
# Processing Record 13 of Set 6 | klaksvik
# Processing Record 14 of Set 6 | dodola
# Processing Record 15 of Set 6 | zhigansk
# Processing Record 16 of Set 6 | lima
# Processing Record 17 of Set 6 | kyabe
# Processing Record 18 of Set 6 | kathmandu
# Processing Record 19 of Set 6 | watsa
# Processing Record 20 of Set 6 | csepreg
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 23 of Set 6 | boo
# Processing Record 24 of Set 6 | hohhot
# Processing Record 25 of Set 6 | polunochnoye
# Processing Record 26 of Set 6 | kutum
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | kurilsk
# Processing Record 29 of Set 6 | thompson
# Processing Record 30 of Set 6 | ayios matthaios
# City not found. Skipping...
# Processing Record 31 of Set 6 | yar-sale
# Processing Record 32 of Set 6 | qandala
# Processing Record 33 of Set 6 | kisarazu
# Processing Record 34 of Set 6 | kangaatsiaq
# Processing Record 35 of Set 6 | port-gentil
# Processing Record 36 of Set 6 | vao
# Processing Record 37 of Set 6 | tala
# Processing Record 38 of Set 6 | dongning
# Processing Record 39 of Set 6 | bethel
# Processing Record 40 of Set 6 | the valley
# Processing Record 41 of Set 6 | bogovarovo
# Processing Record 42 of Set 6 | poya
# Processing Record 43 of Set 6 | villacarrillo
# Processing Record 44 of Set 6 | monclova
# Processing Record 45 of Set 6 | suoyarvi
# Processing Record 46 of Set 6 | curuguaty
# Processing Record 47 of Set 6 | murdochville
# Processing Record 48 of Set 6 | panaba
# Processing Record 49 of Set 6 | pevek
# Processing Record 50 of Set 6 | kavaratti
# Processing Record 1 of Set 7 | silver city
# Processing Record 2 of Set 7 | kjollefjord
# Processing Record 3 of Set 7 | saint george
# Processing Record 4 of Set 7 | ajdabiya
# Processing Record 5 of Set 7 | palana
# Processing Record 6 of Set 7 | murgab
# Processing Record 7 of Set 7 | kulhudhuffushi
# Processing Record 8 of Set 7 | pavlovsk
# Processing Record 9 of Set 7 | wattegama
# Processing Record 10 of Set 7 | unecha
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | dryden
# Processing Record 13 of Set 7 | sur
# Processing Record 14 of Set 7 | zhaotong
# Processing Record 15 of Set 7 | kota tinggi
# Processing Record 16 of Set 7 | nanortalik
# Processing Record 17 of Set 7 | fernie
# Processing Record 18 of Set 7 | sibolga
# Processing Record 19 of Set 7 | antofagasta
# Processing Record 20 of Set 7 | kuala terengganu
# Processing Record 21 of Set 7 | calvia
# Processing Record 22 of Set 7 | hambantota
# Processing Record 23 of Set 7 | manado
# Processing Record 24 of Set 7 | vokhtoga
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | fort morgan
# Processing Record 27 of Set 7 | provideniya
# Processing Record 28 of Set 7 | boa vista
# Processing Record 29 of Set 7 | roald
# Processing Record 30 of Set 7 | boyuibe
# Processing Record 31 of Set 7 | ahipara
# Processing Record 32 of Set 7 | karaidel
# Processing Record 33 of Set 7 | sola
# Processing Record 34 of Set 7 | moree
# Processing Record 35 of Set 7 | ukiah
# Processing Record 36 of Set 7 | karratha
# Processing Record 37 of Set 7 | nabire
# Processing Record 38 of Set 7 | de aar
# Processing Record 39 of Set 7 | cap malheureux
# Processing Record 40 of Set 7 | butka
# Processing Record 41 of Set 7 | hirapur
# Processing Record 42 of Set 7 | walsrode
# Processing Record 43 of Set 7 | okhotsk
# Processing Record 44 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 45 of Set 7 | kirakira
# Processing Record 46 of Set 7 | wakema
# Processing Record 47 of Set 7 | port hedland
# Processing Record 48 of Set 7 | iracoubo
# Processing Record 49 of Set 7 | sao joao da barra
# Processing Record 50 of Set 7 | krasnoborsk
# Processing Record 1 of Set 8 | port augusta
# Processing Record 2 of Set 8 | oktyabrskoye
# Processing Record 3 of Set 8 | lisala
# Processing Record 4 of Set 8 | airai
# Processing Record 5 of Set 8 | rio grande
# Processing Record 6 of Set 8 | najran
# Processing Record 7 of Set 8 | anadyr
# Processing Record 8 of Set 8 | tymovskoye
# Processing Record 9 of Set 8 | znamenka
# Processing Record 10 of Set 8 | ust-maya
# Processing Record 11 of Set 8 | nelson bay
# Processing Record 12 of Set 8 | bireun
# Processing Record 13 of Set 8 | baijiantan
# Processing Record 14 of Set 8 | narsaq
# Processing Record 15 of Set 8 | seymour
# Processing Record 16 of Set 8 | kaa-khem
# Processing Record 17 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | almaznyy
# Processing Record 19 of Set 8 | rjukan
# Processing Record 20 of Set 8 | cavalcante
# Processing Record 21 of Set 8 | fort nelson
# Processing Record 22 of Set 8 | shenjiamen
# Processing Record 23 of Set 8 | yokadouma
# Processing Record 24 of Set 8 | coihueco
# Processing Record 25 of Set 8 | hun
# Processing Record 26 of Set 8 | rach gia
# Processing Record 27 of Set 8 | tokur
# Processing Record 28 of Set 8 | mercedes
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | hearst
# Processing Record 31 of Set 8 | benjamin hill
# Processing Record 32 of Set 8 | lensk
# Processing Record 33 of Set 8 | bathsheba
# Processing Record 34 of Set 8 | gushikawa
# Processing Record 35 of Set 8 | morro da fumaca
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | chegutu
# Processing Record 38 of Set 8 | dongfeng
# Processing Record 39 of Set 8 | mwinilunga
# Processing Record 40 of Set 8 | pincher creek
# Processing Record 41 of Set 8 | hofn
# Processing Record 42 of Set 8 | puerto colombia
# Processing Record 43 of Set 8 | pontes e lacerda
# Processing Record 44 of Set 8 | vaitape
# Processing Record 45 of Set 8 | port blair
# Processing Record 46 of Set 8 | zunyi
# Processing Record 47 of Set 8 | langfang
# Processing Record 48 of Set 8 | vrangel
# Processing Record 49 of Set 8 | santa ana
# Processing Record 50 of Set 8 | palmer
# Processing Record 1 of Set 9 | rayevskiy
# Processing Record 2 of Set 9 | abha
# Processing Record 3 of Set 9 | oga
# Processing Record 4 of Set 9 | spornoye
# Processing Record 5 of Set 9 | talnakh
# Processing Record 6 of Set 9 | basco
# Processing Record 7 of Set 9 | beira
# Processing Record 8 of Set 9 | kinwat
# Processing Record 9 of Set 9 | urrao
# Processing Record 10 of Set 9 | imeni poliny osipenko
# Processing Record 11 of Set 9 | constitucion
# Processing Record 12 of Set 9 | tarpon springs
# Processing Record 13 of Set 9 | inuvik
# Processing Record 14 of Set 9 | vila velha
# Processing Record 15 of Set 9 | muros
# Processing Record 16 of Set 9 | khani
# Processing Record 17 of Set 9 | ankazoabo
# Processing Record 18 of Set 9 | ginda
# Processing Record 19 of Set 9 | novokuznetsk
# Processing Record 20 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 9 | champerico
# Processing Record 22 of Set 9 | kitimat
# Processing Record 23 of Set 9 | yagodnoye
# Processing Record 24 of Set 9 | pokhara
# Processing Record 25 of Set 9 | tolstoy-yurt
# Processing Record 26 of Set 9 | mastic beach
# Processing Record 27 of Set 9 | bara
# Processing Record 28 of Set 9 | villarrica
# Processing Record 29 of Set 9 | xai-xai
# Processing Record 30 of Set 9 | cradock
# Processing Record 31 of Set 9 | buraydah
# Processing Record 32 of Set 9 | gaimersheim
# Processing Record 33 of Set 9 | villa altagracia
# Processing Record 34 of Set 9 | bud
# Processing Record 35 of Set 9 | along
# Processing Record 36 of Set 9 | vilhena
# Processing Record 37 of Set 9 | havoysund
# Processing Record 38 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 39 of Set 9 | marzuq
# Processing Record 40 of Set 9 | sibu
# Processing Record 41 of Set 9 | morondava
# Processing Record 42 of Set 9 | itainopolis
# Processing Record 43 of Set 9 | beringovskiy
# Processing Record 44 of Set 9 | atasu
# Processing Record 45 of Set 9 | fukue
# Processing Record 46 of Set 9 | olean
# Processing Record 47 of Set 9 | kedrovyy
# Processing Record 48 of Set 9 | niquero
# Processing Record 49 of Set 9 | asfi
# Processing Record 50 of Set 9 | lichinga
# Processing Record 1 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 2 of Set 10 | apastovo
# Processing Record 3 of Set 10 | quatre cocos
# Processing Record 4 of Set 10 | buckeye
# Processing Record 5 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 10 | rehoboth
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | centenario do sul
# Processing Record 9 of Set 10 | bengkulu
# Processing Record 10 of Set 10 | lata
# Processing Record 11 of Set 10 | saint-georges
# Processing Record 12 of Set 10 | chilca
# Processing Record 13 of Set 10 | date
# Processing Record 14 of Set 10 | hof
# Processing Record 15 of Set 10 | orgun
# City not found. Skipping...
# Processing Record 16 of Set 10 | sabha
# Processing Record 17 of Set 10 | rojhan
# Processing Record 18 of Set 10 | coquimbo
# Processing Record 19 of Set 10 | berbera
# Processing Record 20 of Set 10 | ponta delgada
# Processing Record 21 of Set 10 | chitral
# Processing Record 22 of Set 10 | kigoma
# Processing Record 23 of Set 10 | yaring
# Processing Record 24 of Set 10 | lavrentiya
# Processing Record 25 of Set 10 | mazatlan
# Processing Record 26 of Set 10 | lamar
# Processing Record 27 of Set 10 | tilichiki
# Processing Record 28 of Set 10 | cotonou
# Processing Record 29 of Set 10 | vulcan
# Processing Record 30 of Set 10 | boyolangu
# Processing Record 31 of Set 10 | robertsport
# Processing Record 32 of Set 10 | cayenne
# Processing Record 33 of Set 10 | sukumo
# Processing Record 34 of Set 10 | azare
# Processing Record 35 of Set 10 | seddon
# Processing Record 36 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 10 | kuzino
# Processing Record 38 of Set 10 | vanderhoof
# Processing Record 39 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 40 of Set 10 | bilma
# Processing Record 41 of Set 10 | bairiki
# Processing Record 42 of Set 10 | kaabong
# Processing Record 43 of Set 10 | madang
# Processing Record 44 of Set 10 | manaure
# Processing Record 45 of Set 10 | arlit
# Processing Record 46 of Set 10 | northam
# Processing Record 47 of Set 10 | banda aceh
# Processing Record 48 of Set 10 | kon tum
# Processing Record 49 of Set 10 | isangel
# Processing Record 50 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 11 | buin
# Processing Record 2 of Set 11 | tuatapere
# Processing Record 3 of Set 11 | kahului
# Processing Record 4 of Set 11 | praia
# Processing Record 5 of Set 11 | sarkand
# Processing Record 6 of Set 11 | port macquarie
# Processing Record 7 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 11 | nueva helvecia
# Processing Record 9 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 10 of Set 11 | traverse city
# Processing Record 11 of Set 11 | fountain hills
# Processing Record 12 of Set 11 | safaga
# Processing Record 13 of Set 11 | conceicao da barra
# Processing Record 14 of Set 11 | ornskoldsvik
# Processing Record 15 of Set 11 | bambui
# Processing Record 16 of Set 11 | ewa beach
# Processing Record 17 of Set 11 | maceio
# Processing Record 18 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 11 | estevan
# Processing Record 20 of Set 11 | mugreyevskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | flinders
# Processing Record 22 of Set 11 | santa rosa de aguan
# Processing Record 23 of Set 11 | chutung
# City not found. Skipping...
# Processing Record 24 of Set 11 | pochutla
# Processing Record 25 of Set 11 | tiznit
# Processing Record 26 of Set 11 | raduzhnyy
# Processing Record 27 of Set 11 | ketchikan
# Processing Record 28 of Set 11 | le port
# Processing Record 29 of Set 11 | miedzyrzecz
# Processing Record 30 of Set 11 | ust-kuyga
# Processing Record 31 of Set 11 | shelburne
# Processing Record 32 of Set 11 | itarema
# Processing Record 33 of Set 11 | parakou
# Processing Record 34 of Set 11 | pak thong chai
# Processing Record 35 of Set 11 | ningbo
# Processing Record 36 of Set 11 | palu
# Processing Record 37 of Set 11 | gafanha da encarnacao
# Processing Record 38 of Set 11 | bull savanna
# Processing Record 39 of Set 11 | nerchinskiy zavod
# Processing Record 40 of Set 11 | eshowe
# Processing Record 41 of Set 11 | bahia blanca
# Processing Record 42 of Set 11 | canavieiras
# Processing Record 43 of Set 11 | banjarmasin
# Processing Record 44 of Set 11 | phangnga
# Processing Record 45 of Set 11 | shu
# Processing Record 46 of Set 11 | raichur
# Processing Record 47 of Set 11 | praia da vitoria
# Processing Record 48 of Set 11 | marsh harbour
# Processing Record 49 of Set 11 | coxim
# Processing Record 50 of Set 11 | acajutla
# Processing Record 1 of Set 12 | altus
# Processing Record 2 of Set 12 | marawi
# Processing Record 3 of Set 12 | paita
# Processing Record 4 of Set 12 | kozhva
# Processing Record 5 of Set 12 | oussouye
# Processing Record 6 of Set 12 | galesong
# Processing Record 7 of Set 12 | ishigaki
# Processing Record 8 of Set 12 | vakhrushev
# Processing Record 9 of Set 12 | port hardy
# Processing Record 10 of Set 12 | bagdarin
# Processing Record 11 of Set 12 | aksu
# Processing Record 12 of Set 12 | lenger
# Processing Record 13 of Set 12 | asau
# Processing Record 14 of Set 12 | portobelo
# Processing Record 15 of Set 12 | tazovskiy
# Processing Record 16 of Set 12 | saint-pierre
# Processing Record 17 of Set 12 | shihezi
# Processing Record 18 of Set 12 | sechura
# Processing Record 19 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 12 | boguchany
# Processing Record 21 of Set 12 | mackenzie
# Processing Record 22 of Set 12 | sheridan
# Processing Record 23 of Set 12 | pitimbu
# Processing Record 24 of Set 12 | sao filipe
# Processing Record 25 of Set 12 | college
# Processing Record 26 of Set 12 | leningradskiy
# Processing Record 27 of Set 12 | petropavlovka
# Processing Record 28 of Set 12 | brownwood
# Processing Record 29 of Set 12 | port lincoln
# Processing Record 30 of Set 12 | kipen
# Processing Record 31 of Set 12 | bhuj
# Processing Record 32 of Set 12 | nyurba
# Processing Record 33 of Set 12 | cap-aux-meules
# Processing Record 34 of Set 12 | ushibuka
# Processing Record 35 of Set 12 | bom jesus
# Processing Record 36 of Set 12 | aquin
# Processing Record 37 of Set 12 | merced
# Processing Record 38 of Set 12 | sulangan
# Processing Record 39 of Set 12 | teya
# Processing Record 40 of Set 12 | benguela
# Processing Record 41 of Set 12 | mayumba
# Processing Record 42 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 12 | harper
# Processing Record 44 of Set 12 | adet
# Processing Record 45 of Set 12 | meulaboh
# Processing Record 46 of Set 12 | farafangana
# Processing Record 47 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 12 | tautira
# Processing Record 49 of Set 12 | ibiapina
# Processing Record 50 of Set 12 | wakkanai
# Processing Record 1 of Set 13 | rio gallegos
# Processing Record 2 of Set 13 | batagay-alyta
# Processing Record 3 of Set 13 | vangaindrano
# Processing Record 4 of Set 13 | komsomolskiy
# Processing Record 5 of Set 13 | saldanha
# Processing Record 6 of Set 13 | novyy urgal
# Processing Record 7 of Set 13 | sept-iles
# Processing Record 8 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 13 | marienburg
# Processing Record 10 of Set 13 | jacareacanga
# Processing Record 11 of Set 13 | marsa matruh
# Processing Record 12 of Set 13 | luwuk
# Processing Record 13 of Set 13 | gorontalo
# Processing Record 14 of Set 13 | newala
# Processing Record 15 of Set 13 | miraflores
# Processing Record 16 of Set 13 | mexico
# Processing Record 17 of Set 13 | sao paulo de olivenca
# Processing Record 18 of Set 13 | baoqing
# Processing Record 19 of Set 13 | creel
# Processing Record 20 of Set 13 | jinka
# Processing Record 21 of Set 13 | bhachau
# Processing Record 22 of Set 13 | juneau
# Processing Record 23 of Set 13 | nagaur
# Processing Record 24 of Set 13 | sambava
# Processing Record 25 of Set 13 | kasongo-lunda
# Processing Record 26 of Set 13 | ghanzi
# Processing Record 27 of Set 13 | saint-pacome
# City not found. Skipping...
# Processing Record 28 of Set 13 | lotofaga
# Processing Record 29 of Set 13 | lewiston
# Processing Record 30 of Set 13 | coos bay
# Processing Record 31 of Set 13 | tatawin
# Processing Record 32 of Set 13 | atar
# Processing Record 33 of Set 13 | warangal
# Processing Record 34 of Set 13 | fort myers beach
# Processing Record 35 of Set 13 | maamba
# Processing Record 36 of Set 13 | kamaishi
# Processing Record 37 of Set 13 | half moon bay
# Processing Record 38 of Set 13 | brae
# Processing Record 39 of Set 13 | hovd
# Processing Record 40 of Set 13 | taltal
# Processing Record 41 of Set 13 | visnes
# Processing Record 42 of Set 13 | chiang kham
# Processing Record 43 of Set 13 | mangrol
# Processing Record 44 of Set 13 | sokur
# Processing Record 45 of Set 13 | la ronge
# Processing Record 46 of Set 13 | vanavara
# Processing Record 47 of Set 13 | bangassou
# Processing Record 48 of Set 13 | biloli
# Processing Record 49 of Set 13 | ahuimanu
# Processing Record 50 of Set 13 | teterow
# Processing Record 1 of Set 14 | riberalta
# Processing Record 2 of Set 14 | korla
# Processing Record 3 of Set 14 | ulaangom
# Processing Record 4 of Set 14 | turukhansk
# Processing Record 5 of Set 14 | skjervoy
# Processing Record 6 of Set 14 | manzhouli
# Processing Record 7 of Set 14 | anqing
# Processing Record 8 of Set 14 | chaupal
# Processing Record 9 of Set 14 | swarzedz
# Processing Record 10 of Set 14 | baffa
# Processing Record 11 of Set 14 | winnemucca
# Processing Record 12 of Set 14 | zhangye
# Processing Record 13 of Set 14 | camacha
# Processing Record 14 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 15 of Set 14 | bacolod
# Processing Record 16 of Set 14 | kodinsk
# Processing Record 17 of Set 14 | thilogne
# City not found. Skipping...
# Processing Record 18 of Set 14 | baykit
# Processing Record 19 of Set 14 | antalaha
# Processing Record 20 of Set 14 | akureyri
# Processing Record 21 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 14 | ust-ilimsk
# Processing Record 23 of Set 14 | turan
# Processing Record 24 of Set 14 | nouadhibou
# Processing Record 25 of Set 14 | cockburn town
# Processing Record 26 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 14 | mormugao
# Processing Record 28 of Set 14 | santa rosa
# Processing Record 29 of Set 14 | beyneu
# Processing Record 30 of Set 14 | sitka
# Processing Record 31 of Set 14 | faya
# Processing Record 32 of Set 14 | san julian
# Processing Record 33 of Set 14 | qaqortoq
# Processing Record 34 of Set 14 | tiruppur
# Processing Record 35 of Set 14 | monterey
# Processing Record 36 of Set 14 | hualmay
# Processing Record 37 of Set 14 | nhulunbuy
# Processing Record 38 of Set 14 | bolu
# Processing Record 39 of Set 14 | olga
# Processing Record 40 of Set 14 | ejido
# Processing Record 41 of Set 14 | abu dhabi
# Processing Record 42 of Set 14 | kindia
# Processing Record 43 of Set 14 | tefe
# Processing Record 44 of Set 14 | monte santo
# Processing Record 45 of Set 14 | calabozo
# Processing Record 46 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 14 | mount isa
# Processing Record 48 of Set 14 | greymouth
# Processing Record 49 of Set 14 | san cristobal
# Processing Record 50 of Set 14 | semey
# Processing Record 1 of Set 15 | acuna
# City not found. Skipping...
# Processing Record 2 of Set 15 | chippewa falls
# Processing Record 3 of Set 15 | taywarah
# Processing Record 4 of Set 15 | quelimane
# Processing Record 5 of Set 15 | north bend
# Processing Record 6 of Set 15 | trinidad
# Processing Record 7 of Set 15 | gamba
# Processing Record 8 of Set 15 | linkoping
# Processing Record 9 of Set 15 | camflora
# City not found. Skipping...
# Processing Record 10 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 15 | kazachinskoye
# Processing Record 12 of Set 15 | ostashkov
# Processing Record 13 of Set 15 | stromness
# Processing Record 14 of Set 15 | yumen
# Processing Record 15 of Set 15 | yeniseysk
# Processing Record 16 of Set 15 | manokwari
# Processing Record 17 of Set 15 | ribeira brava
# Processing Record 18 of Set 15 | puerto escondido
# Processing Record 19 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 15 | madingou
# Processing Record 21 of Set 15 | magalia
# Processing Record 22 of Set 15 | sao miguel do araguaia
# Processing Record 23 of Set 15 | alexandria
# Processing Record 24 of Set 15 | tateyama
# Processing Record 25 of Set 15 | mumford
# Processing Record 26 of Set 15 | shubarkuduk
# Processing Record 27 of Set 15 | pundaguitan
# Processing Record 28 of Set 15 | ambovombe
# Processing Record 29 of Set 15 | hirado
# Processing Record 30 of Set 15 | cartagena
# Processing Record 31 of Set 15 | el rosario
# Processing Record 32 of Set 15 | kourou
# Processing Record 33 of Set 15 | raahe
# Processing Record 34 of Set 15 | magadan
# Processing Record 35 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 15 | waingapu
# Processing Record 37 of Set 15 | netivot
# Processing Record 38 of Set 15 | zlitan
# Processing Record 39 of Set 15 | kabare
# Processing Record 40 of Set 15 | nsanje
# Processing Record 41 of Set 15 | cayhagan
# Processing Record 42 of Set 15 | coari
# Processing Record 43 of Set 15 | grindavik
# Processing Record 44 of Set 15 | ust-nera
# Processing Record 45 of Set 15 | partenit
# Processing Record 46 of Set 15 | santa marta
# Processing Record 47 of Set 15 | cusuna
# Processing Record 48 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 49 of Set 15 | soyo
# Processing Record 50 of Set 15 | mudyuga
# City not found. Skipping...
# Processing Record 1 of Set 16 | boende
# Processing Record 2 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 16 | vung tau
# Processing Record 4 of Set 16 | abu samrah
# Processing Record 5 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 16 | kaunas
# Processing Record 7 of Set 16 | westport
# Processing Record 8 of Set 16 | paramonga
# Processing Record 9 of Set 16 | anloga
# Processing Record 10 of Set 16 | isla vista
# Processing Record 11 of Set 16 | bouar
# Processing Record 12 of Set 16 | ayorou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 701

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Coihaique      CL -45.5752  -72.0662     56.01        47
# 1           Qasigiannguit      GL  68.8193  -51.1922     17.71        91
# 2                 Rikitea      PF -23.1203 -134.9692     74.25        67
# 3                  Hasaki      JP  35.7333  140.8333     43.20        37
# 4               Hithadhoo      MV  -0.6000   73.0833     80.13        75
# 5               Mahebourg      MU -20.4081   57.7000     74.25        81
# 6               Esperance      AU -33.8667  121.9000     65.86        54
# 7       Doembang Nangbuat      TH  14.8333  100.1000     70.05        67
# 8                  Hobart      AU -42.8794  147.3294     53.22        87
# 9  Santa Cruz De Tenerife      ES  28.4682  -16.2546     68.61        83
#
#    Cloudiness  Wind Speed Current Description
# 0           0        5.75           clear sky
# 1         100        4.76     overcast clouds
# 2          30        7.81    scattered clouds
# 3          37        8.63    scattered clouds
# 4          94        9.98     overcast clouds
# 5          49       11.18          light rain
# 6          35       14.76    scattered clouds
# 7          30        7.52    scattered clouds
# 8          75       16.11       broken clouds
# 9          75       15.01       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Coihaique      CL -45.5752  -72.0662     56.01        47           0
# 1  Qasigiannguit      GL  68.8193  -51.1922     17.71        91         100
# 2        Rikitea      PF -23.1203 -134.9692     74.25        67          30
# 3         Hasaki      JP  35.7333  140.8333     43.20        37          37
# 4      Hithadhoo      MV  -0.6000   73.0833     80.13        75          94
#
#    Wind Speed Current Description
# 0        5.75           clear sky
# 1        4.76     overcast clouds
# 2        7.81    scattered clouds
# 3        8.63    scattered clouds
# 4        9.98     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
city_data_df.to_csv("WeatherPy_Database.csv",index_label="id")
